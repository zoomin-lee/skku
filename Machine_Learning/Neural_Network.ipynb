# %%
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/ML&DM/Machine_Learning/ctr_data_20000.csv')
data.columns
# Out:
# Index(['id', 'click', 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain',
#        'site_category', 'app_id', 'app_domain', 'app_category', 'device_id',
#        'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14',
#        'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21'],
#       dtype='object')

# %%
data = data.drop(['id', 'hour','device_id', 'device_ip'], axis =1) # 쓸모없는 칼럼들 삭제

# %%
data.head()
# Out:
#    click    C1  banner_pos   site_id site_domain  ...   C17 C18 C19     C20  C21
# 0      0  1005           0  1fbe01fe    f3845767  ...  1722   0  35      -1   79
# 1      0  1005           0  1fbe01fe    f3845767  ...  1722   0  35  100084   79
# 2      0  1005           0  1fbe01fe    f3845767  ...  1722   0  35  100084   79
# 3      0  1005           0  1fbe01fe    f3845767  ...  1722   0  35  100084   79
# 4      0  1005           1  fe8cc448    9166c161  ...  2161   0  35      -1  157
#
# [5 rows x 20 columns]

# %%
from sklearn.feature_extraction import DictVectorizer # feature들을 one-hot encoding으로 바꿔줌

data_x = data.loc[:, data.columns != 'click'].astype('str')
data_y = data.loc[:, data.columns == 'click'].astype('int').values.ravel()

train_x, test_x = data_x[0:15000], data_x[15000:]
train_y, test_y = data_y[0:15000], data_y[15000:]

dict_one_hot_encoder = DictVectorizer(sparse=False)
onehot_train_x = dict_one_hot_encoder.fit_transform(train_x.to_dict('records'))
onehot_test_x = dict_one_hot_encoder.transform(test_x.to_dict('records'))

# %%
train_x.head()
# Out:
#      C1 banner_pos   site_id site_domain  ... C18 C19     C20  C21
# 0  1005          0  1fbe01fe    f3845767  ...   0  35      -1   79
# 1  1005          0  1fbe01fe    f3845767  ...   0  35  100084   79
# 2  1005          0  1fbe01fe    f3845767  ...   0  35  100084   79
# 3  1005          0  1fbe01fe    f3845767  ...   0  35  100084   79
# 4  1005          1  fe8cc448    9166c161  ...   0  35      -1  157
#
# [5 rows x 19 columns]

# %%
test_y
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import roc_auc_score

clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5,2), random_state=1)
#hidden layer가 2층으로 5개, 2개로 구성되어있음
clf.fit(onehot_train_x, train_y)
pos_prob = clf.predict_proba(onehot_test_x)[:,1]
print("The ROC AUC on testing set is {0:3f}".format(roc_auc_score(test_y, pos_prob)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-099f251b82d5> in <module>()
#       4 clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5,2), random_state=1)
#       5 #hidden layer가 2층으로 5개, 2개로 구성되어있음
# ----> 6 clf.fit(onehot_train_x, train_y)
#       7 pos_prob = clf.predict_proba(onehot_test_x)[:,1]
#       8 print("The ROC AUC on testing set is {0:3f}".format(roc_auc_score(test_y, pos_prob)))
#
# NameError: name 'onehot_train_x' is not defined
